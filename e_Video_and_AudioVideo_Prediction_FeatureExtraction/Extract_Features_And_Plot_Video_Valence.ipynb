# %%
import timeit
import os
import sys
sys.path.insert(0, '/media/rb/Omega/0. Thesis Linux/TDD Code/caffe-action_recog/python') #To Look For .py Files in this directory
import caffe
import scipy.io
import scipy as sp
import numpy as np
from pylab import *
from sklearn.metrics import mean_squared_error #For RMSE Calculation
from math import sqrt                          #For RMSE Calculation
import pickle                                  #For saving predicted data externally
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline
print 'Done'
# Out:
# Done

# %%
testnum = '31';

tic = timeit.default_timer();
model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
toc = timeit.default_timer();
time_elapsed = toc - tic; #elapsed time in seconds
print time_elapsed
# Out:
# 0.310377866712
# Complete
# 297.57775116

# %%
testnum = '30';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.223476913617
# Complete

# %%
testnum = '31';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.309134600901
# Complete

# %%
testnum = '52';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.549250864145
# Complete

# %%
testnum = '54';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.2990006217
# Complete

# %%
testnum = '59';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.188165605811
# Complete

# %%
testnum = '61';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.136176368609
# Complete

# %%
testnum = '65';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.144558768617
# Complete

# %%
testnum = '67';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.158356986167
# Complete

# %%
testnum = '72';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.130913040203
# Complete

# %%
testnum = '73';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.157665593397
# Complete

# %%
testnum = '76';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.188213184131
# Complete

# %%
testnum = '78';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.533899990689
# Complete

# %%
testnum = '83';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.252704018917
# Complete

# %%
testnum = '84';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.313411242373
# Complete

# %%
testnum = '95';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.24681892724
# Complete

# %%
testnum = '96';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.146963182569
# Complete

# %%
testnum = '101';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.296626978719
# Complete

# %%
testnum = '103';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.215539196814
# Complete

# %%
testnum = '107';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.482320164758
# Complete

# %%
testnum = '108';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.423265620042
# Complete

# %%
testnum = '109';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.686138213213
# Complete

# %%
testnum = '128';

model = 'deploy_video_Valence.prototxt';
thousand = '15';
weights = 'outputModel_video_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as T :
    path_list = T.readlines()

predicted_value_arr = np.zeros((len(path_list), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list), 1),dtype="f4")

if not os.path.exists('VideoFeaturesValence'):
    os.makedirs('VideoFeaturesValence')
    
feature_list_file = open( 'VideoFeaturesValence/FeatureList_' + testnum + '_Video_Valence.txt', 'w') 
for i,l in enumerate(path_list):
    sp = l.split(' ')
    img = caffe.io.load_image(sp[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    out = net.forward()
    
    feature_array = net.blobs['fc1_v'].data
    predicted_value = net.blobs['fc2_v'].data
    actual_value = float(sp[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp[0].split('/') 
    directory = 'VideoFeaturesValence/' + folddir[1];
    filename = directory + '/Video' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_video' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_video' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.086489931103
# Complete
