# %%
import timeit
import os
import sys
sys.path.insert(0, '/media/rb/Omega/0. Thesis Linux/TDD Code/caffe-action_recog/python') #To Look For .py Files in this directory
import caffe
import scipy.io
import scipy as sp
import numpy as np
from pylab import *
from sklearn.metrics import mean_squared_error #For RMSE Calculation
from math import sqrt                          #For RMSE Calculation
import pickle                                  #For saving predicted data externally
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline
print 'Done'
# Out:
# Done

# %%
testnum = '31';

tic = timeit.default_timer();
model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
toc = timeit.default_timer();
time_elapsed = toc - tic; #elapsed time in seconds
print time_elapsed
# Out:
# 0.322506554448
# Complete
# 1249.30240417

# %%
testnum = '30';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.249030513289
# Complete

# %%
testnum = '31';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.481079829462
# Complete

# %%
testnum = '52';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.414206443814
# Complete

# %%
testnum = '54';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.448847061302
# Complete

# %%
testnum = '59';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.318678023589
# Complete

# %%
testnum = '61';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.364596375732
# Complete

# %%
testnum = '65';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.19550101719
# Complete

# %%
testnum = '67';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.233684045825
# Complete

# %%
testnum = '72';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.11328300113
# Complete

# %%
testnum = '73';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.142853568796
# Complete

# %%
testnum = '76';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.204963915676
# Complete

# %%
testnum = '78';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.536620927139
# Complete

# %%
testnum = '83';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.20666092014
# Complete

# %%
testnum = '84';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.276534228847
# Complete

# %%
testnum = '95';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.216362027356
# Complete

# %%
testnum = '96';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.133527534929
# Complete

# %%
testnum = '101';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.258916945619
# Complete

# %%
testnum = '103';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.162449348102
# Complete

# %%
testnum = '107';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.652342470819
# Complete

# %%
testnum = '108';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.372432882516
# Complete

# %%
testnum = '109';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.476057332057
# Complete

# %%
testnum = '128';

model = 'deploy_audiovideo_Valence.prototxt';
thousand = '15';
weights = 'outputModel_audiovideo_iter_' + thousand + '000_Valence.caffemodel';   

net = caffe.Net(model,weights,caffe.TEST);

with open( 'List_' + testnum + '_Audio_Valence.txt', 'r' ) as TA :
    path_list_a = TA.readlines()
with open( 'List_' + testnum + '_Video_Valence.txt', 'r' ) as TV :
    path_list_v = TV.readlines()
    
if not os.path.exists('AudioVideoFeaturesValence'):
    os.makedirs('AudioVideoFeaturesValence')

feature_list_file = open( 'AudioVideoFeaturesValence/FeatureList_' + testnum + '_AudioVideo_Valence.txt', 'w') 

predicted_value_arr = np.zeros((len(path_list_a), 1),dtype="f4")
actual_value_arr = np.zeros((len(path_list_v), 1),dtype="f4")

for i in range(len(path_list_a)):
    sp_v = path_list_v[i].split(' ')
    img = caffe.io.load_image(sp_v[0], color=False )
    img = caffe.io.resize( img, (128, 128, 1) )
    img = np.transpose(img, (2,0,1))
    net.blobs['data_v'].data[...] = img
    
    sp_a = path_list_a[i].split(' ')    
    f = scipy.io.loadmat(sp_a[0]) #sp_a[0] is matfilename
    X_samples = f.get('samples')
    X_samples = np.transpose(X_samples,(1,0))
    X_samples = X_samples[np.newaxis, :, :] #(n_samples, n_channels, height, width)
    net.blobs['data_a'].data[...] = X_samples
    
    out = net.forward()
    
    feature_array = net.blobs['concat_av'].data
    predicted_value = net.blobs['fc2_av'].data
    actual_value = float(sp_a[1])
    
    predicted_value_arr[i] = predicted_value
    actual_value_arr[i] = actual_value
    
    folddir = sp_a[0].split('/') 
    directory = 'AudioVideoFeaturesValence/' + folddir[1];
    filename = directory + '/AudioVideo' + filter(str.isdigit, folddir[2]) + 'FeatureValence.mat';
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    scipy.io.savemat(filename, mdict={'feature_array':feature_array,'predicted_value':predicted_value,'actual_value':actual_value})
    feature_list_file.write(filename + '\n')
feature_list_file.close()

plt.plot(arange(len(predicted_value_arr)), predicted_value_arr, 'b',arange(len(actual_value_arr)), actual_value_arr, 'r')

rmse = sqrt(mean_squared_error(actual_value_arr, predicted_value_arr))
print rmse

scipy.io.savemat('actual_value_audiovideo' + testnum + '_Valence.mat', mdict={'a_value': actual_value_arr})
scipy.io.savemat('predicted_value_audiovideo' + testnum + '_' + thousand + 'k_Valence.mat', mdict={'p_value': predicted_value_arr})

print 'Complete'
# Out:
# 0.101366284537
# Complete
